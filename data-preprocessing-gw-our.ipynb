# %% [markdown]
# # Processing of gravitational data
# In this notebook we will apply some signal processing to the gravitational data. Preprocessing is definately required on these signals, and thankfully there is a Python package called [GWpy](https://gwpy.github.io/docs/latest/index.html) that has all functions that are needed. Theory will not be discussed here in detail, but there is plenty of info and code on the topic:
#   * [GW tutorials](https://www.gw-openscience.org/tutorials/)
#   * [Gravitational Wave Open Science Center](https://www.gw-openscience.org/software/)
#   * [A guide to LIGO–Virgo detector noise and extraction of transient gravitational-wave signals](https://iopscience.iop.org/article/10.1088/1361-6382/ab685e)
#
#
# First, install GWpy:

# %%
# !python -m pip install gwpy
# !pip install astropy==4.2.1
# Out:
# Collecting gwpy
#   Downloading gwpy-3.0.5-py3-none-any.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 3.6 MB/s eta 0:00:01
# Collecting ligo-segments>=1.0.0
#   Downloading ligo-segments-1.4.0.tar.gz (51 kB)
#      |████████████████████████████████| 51 kB 5.7 MB/s  eta 0:00:01
# Requirement already satisfied: python-dateutil in /opt/conda/lib/python3.7/site-packages (from gwpy) (2.8.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.7/site-packages (from gwpy) (2.25.1)
# Collecting gwdatafind>=1.1.0
#   Downloading gwdatafind-1.1.3-py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 2.7 MB/s  eta 0:00:01
# Requirement already satisfied: tqdm>=4.10.0 in /opt/conda/lib/python3.7/site-packages (from gwpy) (4.59.0)
# Collecting gwosc>=0.5.3
#   Downloading gwosc-0.7.1-py3-none-any.whl (27 kB)
# Collecting astropy>=4.3.0
#   Downloading astropy-4.3.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (10.7 MB)
#      |████████████████████████████████| 10.7 MB 346 kB/s eta 0:00:01
# Requirement already satisfied: matplotlib>=3.3.0 in /opt/conda/lib/python3.7/site-packages (from gwpy) (3.4.1)
# Collecting ligotimegps>=1.2.1
#   Downloading ligotimegps-2.0.1-py2.py3-none-any.whl (19 kB)
# Collecting h5py>=3.0.0
#   Downloading h5py-3.8.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.3 MB)
#      |████████████████████████████████| 4.3 MB 50.3 MB/s eta 0:00:01
# Requirement already satisfied: scipy>=1.2.0 in /opt/conda/lib/python3.7/site-packages (from gwpy) (1.5.4)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.7/site-packages (from gwpy) (1.19.5)
# Collecting dqsegdb2
#   Downloading dqsegdb2-1.2.1-py3-none-any.whl (25 kB)
# Requirement already satisfied: importlib-metadata in /opt/conda/lib/python3.7/site-packages (from astropy>=4.3.0->gwpy) (3.4.0)
# Collecting pyerfa>=1.7.3
#   Downloading pyerfa-2.0.0.3-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (734 kB)
#      |████████████████████████████████| 734 kB 64.9 MB/s eta 0:00:01
# Collecting igwn-auth-utils>=0.3.1
#   Downloading igwn_auth_utils-1.1.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: cryptography>=2.3 in /opt/conda/lib/python3.7/site-packages (from igwn-auth-utils>=0.3.1->gwdatafind>=1.1.0->gwpy) (3.4.7)
# Collecting safe-netrc>=1.0.0
#   Downloading safe_netrc-1.0.1-py3-none-any.whl (10 kB)
# Collecting scitokens>=1.7.0
#   Downloading scitokens-1.8.1-py3-none-any.whl (31 kB)
# Requirement already satisfied: cffi>=1.12 in /opt/conda/lib/python3.7/site-packages (from cryptography>=2.3->igwn-auth-utils>=0.3.1->gwdatafind>=1.1.0->gwpy) (1.14.5)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.7/site-packages (from cffi>=1.12->cryptography>=2.3->igwn-auth-utils>=0.3.1->gwdatafind>=1.1.0->gwpy) (2.20)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from ligo-segments>=1.0.0->gwpy) (1.15.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib>=3.3.0->gwpy) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.7/site-packages (from matplotlib>=3.3.0->gwpy) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.7/site-packages (from matplotlib>=3.3.0->gwpy) (7.2.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib>=3.3.0->gwpy) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests->gwpy) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests->gwpy) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests->gwpy) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests->gwpy) (2020.12.5)
# Requirement already satisfied: PyJWT>=1.6.1 in /opt/conda/lib/python3.7/site-packages (from scitokens>=1.7.0->igwn-auth-utils>=0.3.1->gwdatafind>=1.1.0->gwpy) (2.0.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata->astropy>=4.3.0->gwpy) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata->astropy>=4.3.0->gwpy) (3.4.1)
# Building wheels for collected packages: ligo-segments
#   Building wheel for ligo-segments (setup.py) ... done
#   Created wheel for ligo-segments: filename=ligo_segments-1.4.0-cp37-cp37m-linux_x86_64.whl size=92896 sha256=b35c480fd94d53b29eba0efc79f63839611c8794845484bd27575852b54375e5
#   Stored in directory: /root/.cache/pip/wheels/09/f9/d4/129b3bb4458d50b56fdc8245ace7c8216d54865fe8d3aebc05
# Successfully built ligo-segments
# Installing collected packages: scitokens, safe-netrc, pyerfa, ligo-segments, igwn-auth-utils, ligotimegps, h5py, gwosc, gwdatafind, dqsegdb2, astropy, gwpy
#   Attempting uninstall: h5py
#     Found existing installation: h5py 2.10.0
#     Uninstalling h5py-2.10.0:
#       Successfully uninstalled h5py-2.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.4.1 requires h5py~=2.10.0, but you have h5py 3.8.0 which is incompatible.
# nnabla 1.19.0 requires h5py<=3.1.0, but you have h5py 3.8.0 which is incompatible.
# Successfully installed astropy-4.3.1 dqsegdb2-1.2.1 gwdatafind-1.1.3 gwosc-0.7.1 gwpy-3.0.5 h5py-3.8.0 igwn-auth-utils-1.1.0 ligo-segments-1.4.0 ligotimegps-2.0.1 pyerfa-2.0.0.3 safe-netrc-1.0.1 scitokens-1.8.1
# Collecting astropy==4.2.1
#   Downloading astropy-4.2.1-cp37-cp37m-manylinux1_x86_64.whl (9.7 MB)
#      |████████████████████████████████| 9.7 MB 343 kB/s eta 0:00:01     |█████████████████▋              | 5.3 MB 74 kB/s eta 0:00:59
# Requirement already satisfied: pyerfa in /opt/conda/lib/python3.7/site-packages (from astropy==4.2.1) (2.0.0.3)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.7/site-packages (from astropy==4.2.1) (1.19.5)
# Installing collected packages: astropy
#   Attempting uninstall: astropy
#     Found existing installation: astropy 4.3.1
#     Uninstalling astropy-4.3.1:
#       Successfully uninstalled astropy-4.3.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gwpy 3.0.5 requires astropy>=4.3.0, but you have astropy 4.2.1 which is incompatible.
# Successfully installed astropy-4.2.1

# %% [markdown]
# And import a few libraries.

# %%
from gwpy.timeseries import TimeSeries
from gwpy.plot import Plot
import numpy as np
from scipy import signal
from sklearn.preprocessing import MinMaxScaler
from PIL import Image
from matplotlib import pyplot as plt

# %% [markdown]
# # Read & plot files
# Let's define helper function to read numpy data and convert into GWpy TimeSeries format and plot the data. All the files are 2s recordings at 2048Hz sample rate from the 3 detectors.

# %%
def read_file(fname):
    data = np.load(fname)
    d1 = TimeSeries(data[0,:], sample_rate=2048)
    d2 = TimeSeries(data[1,:], sample_rate=2048)
    d3 = TimeSeries(data[2,:], sample_rate=2048)
    return d1, d2, d3

def plot_time_data(d1, d2, d3):
    plot = Plot(d1, d2, d3, separate=True, sharex=True, figsize=[12, 10])
    ax = plot.gca()
    ax.set_xlim(0,2)
    ax.set_xlabel('Time [s]')
    plot.show()

# %% [markdown]
# Visualize a file:

# %%
d1, d2, d3 = read_file('../input/g2net-gravitational-wave-detection/train/0/0/0/000a5b6e5c.npy')
plot_time_data(d1, d2, d3)
# Out:
# <Plot size 864x576 with 3 Axes>

# %% [markdown]
# # Preprocess
# Then we will follow the general processing steps outlined in [this article](https://iopscience.iop.org/article/10.1088/1361-6382/ab685e):
# * Apply a window function (Tukey - tapered cosine window) to suppress spectral leakage
# * Whiten the spectrum
# * Bandpass

# %% [markdown]
# ## Apply window function

# %% [markdown]
# The Tukey window looks like this:

# %%
window = signal.tukey(4096)
plt.plot(window);

# %% [markdown]
# Let's look at the signal after windowing:

# %%
d1, d2, d3 = d1*window, d2*window, d3*window
plot_time_data(d1, d2, d3)
# Out:
# <Plot size 864x720 with 3 Axes>

# %% [markdown]
# Take a look at the spectrum - there is a lot of low frequency noise:

# %%
fig2 = d1.asd(fftlength=2).plot(figsize=[12, 6])
plt.xlim(10,1024)
plt.ylim(1e-25, 1e-20);
# Out:
# <Plot size 864x432 with 1 Axes>

# %% [markdown]
# We can easily highpass the data (here with 15Hz highpass frequency):

# %%
fig2b = d1.highpass(15).asd(fftlength=2).plot(figsize=[12, 6])
plt.xlim(10,1024)
plt.ylim(1e-25, 1e-20);
# Out:
# <Plot size 864x432 with 1 Axes>

# %% [markdown]
# ## Spectral whitening and bandpass filtering
# This is super simple with GWpy:

# %%
white_data = d1.whiten(window=("tukey",0.2)) # whiten-function has a built-in window function
bp_data = white_data.bandpass(35, 350) # frequency range 35-350Hz
fig3 = bp_data.plot(figsize=[12, 6])
plt.xlim(0, 2)
ax = plt.gca()
ax.set_title('Whitened and bandpassed')
ax.set_xlabel('Time [s]');
# Out:
# <Plot size 864x432 with 1 Axes>

# %% [markdown]
# Now, we have a preprocessed data that is ready for further analysis. First, let's define a function that combines all the steps above and outputs preprocessed data:

# %%
def preprocess(d1, d2, d3, bandpass=False, lf=35, hf=350):
    white_d1 = d1.whiten(window=("tukey",0.2))
    white_d2 = d2.whiten(window=("tukey",0.2))
    white_d3 = d3.whiten(window=("tukey",0.2))
    if bandpass: # bandpass filter
        bp_d1 = white_d1.bandpass(lf, hf) 
        bp_d2 = white_d2.bandpass(lf, hf)
        bp_d3 = white_d3.bandpass(lf, hf)
        return bp_d1, bp_d2, bp_d3
    else: # only whiten
        return white_d1, white_d2, white_d3

# %% [markdown]
# # Q-Transform
# The Q-Transform is related to the Fourier transform, and very closely related to a wavelet transform. The spectrogram is a possible candidate as input for a CNN model.

# %%
r1, r2, r3 = read_file('../input/g2net-gravitational-wave-detection/train/0/0/0/000a5b6e5c.npy') # this signal has target=1
p1, p2, p3 = preprocess(r1, r2, r3)
hq = p2.q_transform(qrange=(16,32), frange=(30,400), logf=True, whiten=False)
fig4 = hq.plot(figsize=[12, 10])
ax = fig4.gca()
fig4.colorbar(label="Normalised energy")
ax.grid(False)
ax.set_yscale('log')
ax.set_xlabel('Time [s]');
# Out:
# <Plot size 864x720 with 2 Axes>

# %% [markdown]
# ## Combine three channels into one RGB image
# Since we have 3 detectors, we can combine the Q-Transforms as RGB channels into one color image. Let's make a function for that:

# %%
Q_RANGE = (16,32)
F_RANGE = (30,400)

def create_rgb(fname):
    r1, r2, r3 = read_file(fname)
    p1, p2, p3 = preprocess(r1, r2, r3)
    hq1 = p1.q_transform(qrange=Q_RANGE, frange=F_RANGE, logf=True, whiten=False)
    hq2 = p2.q_transform(qrange=Q_RANGE, frange=F_RANGE, logf=True, whiten=False)
    hq3 = p3.q_transform(qrange=Q_RANGE, frange=F_RANGE, logf=True, whiten=False)
    img = np.zeros([hq1.shape[0], hq1.shape[1], 3], dtype=np.uint8)
    scaler = MinMaxScaler()
    img[:,:,0] = 255*scaler.fit_transform(hq1)
    img[:,:,1] = 255*scaler.fit_transform(hq2)
    img[:,:,2] = 255*scaler.fit_transform(hq3)
    return Image.fromarray(img).rotate(90, expand=1).resize((760,760))

# %%
create_rgb('../input/g2net-gravitational-wave-detection/train/0/0/0/000a5b6e5c.npy')
# Out:
# <PIL.Image.Image image mode=RGB size=760x760 at 0x7E5F304D5910>

# %% [markdown]
# Here is a very obvious one (chirp) from the test set:

# %%
create_rgb('../input/g2net-gravitational-wave-detection/test/0/0/2/0021f9dd71.npy')
# Out:
# <PIL.Image.Image image mode=RGB size=760x760 at 0x7E5F3189C990>

# %% [markdown]
# Awesome! (Or crazy?) Next step is to find out if we can train an image classifier with these images...
